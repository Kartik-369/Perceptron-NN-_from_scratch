# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('student_performance_dataset.csv')

# %%
df = df[['final_exam_score', 'study_hours_per_day', 'sleep_hours']]
df = df.dropna()
row,col=df.shape
df=np.array(df)
split_idx=int(row * 0.2)
train_data=df[split_idx:row].T
X_train=train_data[1:col]
Y_train=train_data[0:1]
test_data=df[:split_idx].T
X_test=test_data[1:col]
Y_test=test_data[0:1]

# %%
def forward_prop(X,W1,B1):
    Z1=W1.dot(X)+B1
    A1=Z1
    return Z1,A1

# %%
def loss_f(A1,Y):
    return np.mean((A1-Y)**2)

# %%
def initilize_params():
    np.random.seed(42) 
    W1=np.random.randn(1,2)*np.sqrt(1./2)
    B1=np.zeros((1,1))
    return W1, B1

# %%
def back_prop(X, Y, Z1, A1, W1):
    m=X.shape[1]
    dZ1=2*(A1-Y)
    dL_dW1=1/m*dZ1.dot(X.T)
    dL_dB1=1/m*np.sum(dZ1,axis=1,keepdims=True)
    return dL_dW1,dL_dB1

# %%
def update(W1, B1, dL_dW1, dL_dB1, lrn_rate):
    W1=W1-lrn_rate*dL_dW1
    B1=B1-lrn_rate*dL_dB1
    return W1, B1

# %%
def gradient_descent(X, Y, lrn_rate, itrs):
    W1,B1=initilize_params()
    for i in range(itrs):
        Z1, A1 = forward_prop(X, W1, B1)        
        dL_dW1, dL_dB1 = back_prop(X, Y, Z1, A1, W1)
        W1, B1 = update(W1, B1, dL_dW1, dL_dB1, lrn_rate)
        if i % 100 == 0:
            loss = loss_f(A1, Y)
            print(f'Iteration: {i:4d} | Loss: {loss:.2f}')
    return W1, B1

# %%
final_W1, final_B1 = gradient_descent(X_train, Y_train, 0.01, 10000)
# Out:
# Iteration:    0 | Loss: 3264.64
# Iteration:  100 | Loss: 324.09
# Iteration:  200 | Loss: 322.39
# Iteration:  300 | Loss: 320.85
# Iteration:  400 | Loss: 319.46
# Iteration:  500 | Loss: 318.20
# Iteration:  600 | Loss: 317.07
# Iteration:  700 | Loss: 316.05
# Iteration:  800 | Loss: 315.13
# Iteration:  900 | Loss: 314.29
# Iteration: 1000 | Loss: 313.54
# Iteration: 1100 | Loss: 312.86
# Iteration: 1200 | Loss: 312.25
# Iteration: 1300 | Loss: 311.70
# Iteration: 1400 | Loss: 311.20
# Iteration: 1500 | Loss: 310.75
# Iteration: 1600 | Loss: 310.34
# Iteration: 1700 | Loss: 309.97
# Iteration: 1800 | Loss: 309.64
# Iteration: 1900 | Loss: 309.34
# Iteration: 2000 | Loss: 309.07
# Iteration: 2100 | Loss: 308.83
# Iteration: 2200 | Loss: 308.61
# Iteration: 2300 | Loss: 308.41
# Iteration: 2400 | Loss: 308.23
# Iteration: 2500 | Loss: 308.07
# Iteration: 2600 | Loss: 307.92
# Iteration: 2700 | Loss: 307.79
# Iteration: 2800 | Loss: 307.67
# Iteration: 2900 | Loss: 307.56
# Iteration: 3000 | Loss: 307.46
# Iteration: 3100 | Loss: 307.38
# Iteration: 3200 | Loss: 307.30
